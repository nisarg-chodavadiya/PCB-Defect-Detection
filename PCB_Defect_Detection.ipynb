# %%
# !unzip "/content/drive/MyDrive/Data Science/YOLO/PCB_DATASET_YOLO.zip"
# Out:
# Archive:  /content/drive/MyDrive/Data Science/YOLO/PCB_DATASET_YOLO.zip
#    creating: PCB_DATASET_YOLO/
#   inflating: PCB_DATASET_YOLO/PCB_Dataset.yaml
#    creating: PCB_DATASET_YOLO/test/
#    creating: PCB_DATASET_YOLO/test/images/
#   inflating: PCB_DATASET_YOLO/test/images/01_missing_hole_06.jpg
#   inflating: PCB_DATASET_YOLO/test/images/01_missing_hole_07.jpg
#   inflating: PCB_DATASET_YOLO/test/images/01_mouse_bite_06.jpg
#   inflating: PCB_DATASET_YOLO/test/images/01_mouse_bite_07.jpg
#   inflating: PCB_DATASET_YOLO/test/images/01_open_circuit_06.jpg
#   inflating: PCB_DATASET_YOLO/test/images/01_open_circuit_07.jpg
#   inflating: PCB_DATASET_YOLO/test/images/01_short_06.jpg
#   inflating: PCB_DATASET_YOLO/test/images/01_short_07.jpg
#   inflating: PCB_DATASET_YOLO/test/images/01_spurious_copper_06.jpg
#   inflating: PCB_DATASET_YOLO/test/images/01_spurious_copper_07.jpg
#   inflating: PCB_DATASET_YOLO/test/images/01_spur_06.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 905.3/905.3 kB 49.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Load a model
model = YOLO("yolo11n.pt")
# Out:
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 363MB/s]

# %%
# Train the model
train_results = model.train(
    data="/content/PCB_DATASET_YOLO/PCB_Dataset.yaml",  # path to dataset YAML
    epochs=100,  # number of training epochs
    imgsz=640,  # training image size
    batch=8,
    device=0,  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
)
# Out:
# Ultralytics 8.3.58 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Evaluate model performance on the validation set
metrics = model.val()
# Out:
# Ultralytics 8.3.58 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,583,322 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /content/PCB_DATASET_YOLO/val/labels.cache... 120 images, 0 backgrounds, 0 corrupt: 100%|██████████| 120/120 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:10<00:00,  1.40it/s]
#                    all        120        551      0.877      0.834      0.886      0.452
#           missing_hole         20         95      0.979      0.967      0.978       0.56
#             mouse_bite         20         93      0.784      0.819       0.86      0.428
#           open_circuit         20         88      0.803      0.739      0.823      0.367
#                  short         20         89       0.95      0.888      0.959      0.482
#                   spur         20         92      0.845       0.75      0.802      0.414
# ...

# %%
# Perform object detection on an image
results = model("/content/PCB_DATASET_YOLO/val/images/01_missing_hole_07.jpg")
results[0].show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Perform object detection on an image
results = model("/content/PCB_DATASET_YOLO/val/images/01_mouse_bite_06.jpg")
results[0].show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Perform object detection on an image
results = model("/content/PCB_DATASET_YOLO/val/images/01_short_06.jpg")
results[0].show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Export the model to ONNX format
path = model.export(format="onnx")  # return path to exported model
